# %% [markdown]
# <a href="https://colab.research.google.com/github/rekhachakkara/python_learning/blob/master/Merge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pandas.merge(left, right, how='inner', on=None, left_on=None,
# right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'),
# copy=None, indicator=False, validate=None)

#merge - combining two dataframe with one or more key/ merging two datasets to one dataframe aligning with common rows or columns with the matching attributes
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

user_dataframe = pd.read_csv("/content/drive/MyDrive/Data_set_rekha/user_usage.csv")
user_device_dataframe = pd.read_csv("/content/drive/MyDrive/Data_set_rekha/user_device.csv")
andriod_device_dataframe = pd.read_csv("/content/drive/MyDrive/Data_set_rekha/andriod_devices.csv")
#merging of user_usage and user_device with the common column use_id it will display the matching rows based on use_id
result_merge = pd.merge(user_dataframe,
                 user_device_dataframe[['use_id', 'platform', 'device']],
                 on='use_id')
result_merge.head()
result_merge.tail()
# merge will use the default iner merge / inner join (both have same functionality) to sort the dataframe
#type of merge
    #Inner Merge / Inner join – The default Pandas behaviour, only keep rows where the merge “on” value exists in both the left and right dataframes.
    #Left Merge / Left outer join –  Keep every row in the left dataframe.
    #Where there are missing values of the “on” variable in the right dataframe, add empty / NaN values in the result.
    #Right Merge / Right outer join –  Keep every row in the right dataframe.
    #Where there are missing values of the “on” variable in the left column, add empty / NaN values in the result.
    #Outer Merge / Full outer join – A full outer join returns all the rows from the left dataframe,
    #all the rows from the right dataframe, and matches up rows where possible, with NaNs elsewhere.
# Out:
#        outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb   use_id  \
# 49857                   198.59                   90.49     5191.12  23043.0
# 49858                   198.59                   90.49     3114.67  23044.0
# 49859                   106.65                   82.13     5191.12  23046.0
# 49860                   344.53                   20.53      519.12  23049.0
# 49861                    42.75                   46.83     5191.12  23053.0
#
#       platform                  device
# 49857  android                SM-G900F
# 49858  android                SM-G900F
# 49859  android              Moto G (4)
# 49860  android                SM-G900F
# 49861  android  Vodafone Smart ultra 6

# %%
result_left_merge = pd.merge(user_dataframe,
                 user_device_dataframe[['use_id', 'platform', 'device']],
                 on='use_id',how='left')
result_left_merge.head()
result_left_merge.tail()
# Out:
#        outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb   use_id  \
# 49947                      NaN                     NaN         NaN      NaN
# 49948                      NaN                     NaN         NaN      NaN
# 49949                      NaN                     NaN         NaN      NaN
# 49950                      NaN                     NaN         NaN      NaN
# 49951                    488.7                  906.92     3089.85  25220.0
#
#       platform device
# 49947      NaN    NaN
# 49948      NaN    NaN
# 49949      NaN    NaN
# 49950      NaN    NaN
# 49951      NaN    NaN

# %%
result_right_merge = pd.merge(user_dataframe,
                 user_device_dataframe[['use_id', 'platform', 'device']],
                 on='use_id',how='right')
result_right_merge.head()
result_right_merge.tail()
# Out:
#        outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb   use_id  \
# 49947                      NaN                     NaN         NaN      NaN
# 49948                      NaN                     NaN         NaN      NaN
# 49949                      NaN                     NaN         NaN      NaN
# 49950                      NaN                     NaN         NaN      NaN
# 49951                    42.75                   46.83     5191.12  23053.0
#
#       platform                  device
# 49947      NaN                     NaN
# 49948      NaN                     NaN
# 49949      NaN                     NaN
# 49950      NaN                     NaN
# 49951  android  Vodafone Smart ultra 6

# %%
result_outer_merge = pd.merge(user_dataframe,
                 user_device_dataframe[['use_id', 'platform', 'device']],
                 on='use_id',how='outer',indicator=True)
result_outer_merge.head()
result_outer_merge.tail()
# Out:
#        outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb   use_id  \
# 50037                      NaN                     NaN         NaN  23047.0
# 50038                      NaN                     NaN         NaN  23048.0
# 50039                      NaN                     NaN         NaN  23050.0
# 50040                      NaN                     NaN         NaN  23051.0
# 50041                      NaN                     NaN         NaN  23052.0
#
#       platform         device      _merge
# 50037      ios      iPhone7,1  right_only
# 50038  android  ONEPLUS A3003  right_only
# 50039      ios      iPhone7,2  right_only
# 50040      ios      iPhone7,2  right_only
# 50041      ios      iPhone8,4  right_only

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-3a7442ae5045> in <cell line: 1>()
# ----> 1 result_outer_merge.groupby("manufacturer").agg({
#       2         "outgoing_mins_per_month": "mean",
#       3         "outgoing_sms_per_month": "mean",
#       4         "monthly_mb": "mean",
#       5         "use_id": "count"
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8400         axis = self._get_axis_number(axis)
#    8401
# -> 8402         return DataFrameGroupBy(
#    8403             obj=self,
#    8404             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-cfa98f5699a5> in <cell line: 1>()
# ----> 1 Final_result = pd.merge(result_merge,andriod_device_dataframe,
#       2                   [['manufacturer', 'Model']],
#       3                   left_on='device',
#       4                   right_on='Model',
#       5                   how='left')
#
# TypeError: merge() got multiple values for argument 'how'

# %%
#join dataframe
#join uSed to join one or more column in a dataframe either by index or by an key column
#DataFrame.join(self, other, on=None, how='left', lsuffix='', rsuffix='', sort=False) self optional , other - , on - key column ,
#how (default value - left,right , outer , iner) lsufix - sufix to use from left overlapping oolumnv , rsufix - sufix to use from right overlapping column,
#sort - depend on join type
#----------------------------------
#join dataframe when uving indexex
#-----------------------------------
user_dataframe.join(user_dataframe, lsuffix='_caller', rsuffix='_other')

# %%
left = pd.DataFrame({"A": ["A0", "A1", "A2"], "B": ["B0", "B1", "B2"]}, index=["K0", "K1", "K2"])
right = pd.DataFrame( {"C": ["C0", "C2", "C3"], "D": ["D0", "D2", "D3"]}, index=["K0", "K2", "K3"])
result = left.join(right)
result_key = left.join(right,on='A') # merging with key
print(result)
print(result_key)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2
#      A   B    C    D
# K0  A0  B0  NaN  NaN
# K1  A1  B1  NaN  NaN
# K2  A2  B2  NaN  NaN

# %%
#combine_fisrt dataframe
#update missing value from one  dataframe to otheer dataframe non-missing values to the corresponnding location
df1 = pd.DataFrame(

    [[np.nan, 3.0, 5.0], [-4.6, np.nan, np.nan], [np.nan, 7.0, np.nan]]

)
print(df1)
print('------')
df2 = pd.DataFrame([[-4.6, np.nan, -8.2], [-5.0, 1.6, 4]], index=[1, 2])
print(df2)
print('------combine first--------')
result_combine = df1.combine_first(df2)
print(result_combine)
# Out:
#      0    1    2
# 0  NaN  3.0  5.0
# 1 -4.6  NaN  NaN
# 2  NaN  7.0  NaN
# ------
#      0    1    2
# 1 -4.6  NaN -8.2
# 2 -5.0  1.6  4.0
# ------combine first--------
#      0    1    2
# 0  NaN  3.0  5.0
# 1 -4.6  NaN -8.2
# 2 -5.0  7.0  4.0

# %%
#merge_ordered - combines nueric and time series data with optional filling of  missing data with fill_method
left = pd.DataFrame({"k": ["K0", "K1", "K1", "K2"], "lv": [1, 2, 3, 4], "s": ["a", "b", "c", "d"]})

right = pd.DataFrame({"k": ["K1", "K2", "K4"], "rv": [1, 2, 3]})

pd.merge_ordered(left, right, fill_method="ffill", left_by="s")
# Out:
#      k   lv  s   rv
# 0   K0  1.0  a  NaN
# 1   K1  1.0  a  1.0
# 2   K2  1.0  a  2.0
# 3   K4  1.0  a  3.0
# 4   K1  2.0  b  1.0
# 5   K2  2.0  b  2.0
# 6   K4  2.0  b  3.0
# 7   K1  3.0  c  1.0
# 8   K2  3.0  c  2.0
# 9   K4  3.0  c  3.0
# 10  K1  NaN  d  1.0
# 11  K2  4.0  d  2.0
# 12  K4  4.0  d  3.0

# %%
#merge_asof - ita like a left join instead of matching on neareat key rather than equal key



# importing package
import pandas

# creating data
left = pandas.DataFrame({'a': [1, 5, 10],
                         'left_val': ['a', 'b', 'c']})

right = pandas.DataFrame({'a': [1, 2, 3, 6, 7],
                          'right_val': [1, 2, 3, 6, 7]})

# view data
print(left)
print(right)

# applying merge_asof on data
print(pandas.merge_asof(left, right, on='a'))
print(pandas.merge_asof(left, right, on='a',
                        allow_exact_matches=False))
# Out:
#     a left_val
# 0   1        a
# 1   5        b
# 2  10        c
#    a  right_val
# 0  1          1
# 1  2          2
# 2  3          3
# 3  6          6
# 4  7          7
#     a left_val  right_val
# 0   1        a          1
# 1   5        b          3
# 2  10        c          7
#     a left_val  right_val
# 0   1        a        NaN
# 1   5        b        3.0
# 2  10        c        7.0

# %%
#compare() - compare two dataframe and summarize the difference
result_compare = user_dataframe.compare(user_dataframe)
print(result_compare)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
